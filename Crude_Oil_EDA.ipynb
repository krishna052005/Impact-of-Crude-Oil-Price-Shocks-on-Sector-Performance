# %%
# !pip install yfinance

import yfinance as yf
import pandas as pd

# %%
import yfinance as yf
from google.colab import files

# Define tickers with clear file names
datasets = [
    ("Crude_Oil_Brent", "BZ=F"),
    ("Indigo", "INDIGO.NS"),
    ("Asian_Paints", "ASIANPAINT.NS"),
    ("HUL", "HINDUNILVR.NS"),
    ("Maruti", "MARUTI.NS")
]

# Date range
start_date = "2021-04-05"
end_date = "2026-04-05"

# Loop through each dataset
for name, ticker in datasets:
    print(f"Downloading {name}...")

    df = yf.download(ticker, start=start_date, end=end_date)

    # Reset index to get Date column
    df.reset_index(inplace=True)

    # Save CSV
    file_name = f"{name}.csv"
    df.to_csv(file_name, index=False)

    print(f"{file_name} saved!")

    # Download file to your system
    files.download(file_name)
# Out:
# ...
# /tmp/ipykernel_2694/953491963.py:21: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# Crude_Oil_Brent.csv saved!
# /tmp/ipykernel_2694/953491963.py:21: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date)
# ...
# [*********************100%***********************]  1 of 1 completed
# Indigo.csv saved!
# /tmp/ipykernel_2694/953491963.py:21: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date)
# ...
# [*********************100%***********************]  1 of 1 completed
# Asian_Paints.csv saved!
# /tmp/ipykernel_2694/953491963.py:21: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date)
# ...

# %%
df.columns = df.columns.get_level_values(0)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("/content/Master_data.xlsx")
df.head()
# Out:
#         Date  Oil_Price       Indigo  Asian_Paints          HUL       Maruti  \
# 0 2021-04-05  62.150002  1550.080444   2403.121582  2182.407715  6487.232910
# 1 2021-04-06  62.740002  1574.938477   2499.748535  2214.685791  6470.699707
# 2 2021-04-07  63.160000  1596.951294   2516.020508  2211.880859  6579.674805
# 3 2021-04-08  63.200001  1637.981934   2537.125732  2216.157471  6543.110352
# 4 2021-04-09  62.950001  1644.171509   2518.125977  2276.942627  6543.349609
#
#    Oil_Return  Indigo_Return  Asian_Paints_Return  HUL_Return  Maruti_Return  \
# 0         NaN            NaN                  NaN         NaN            NaN
# 1    0.009493       0.016037             0.040209    0.014790      -0.002549
# 2    0.006694       0.013977             0.006509   -0.001267       0.016841
# 3    0.000633       0.025693             0.008388    0.001933      -0.005557
# 4   -0.003956       0.003779            -0.007489    0.027428       0.000037
#
# ...

# %%
#Convert Date
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# %%
df = df.drop(columns=['Unnamed: 11'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1259 entries, 2021-04-05 to 2026-04-02
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Oil_Price            1259 non-null   float64
#  1   Indigo               1197 non-null   float64
#  2   Asian_Paints         1197 non-null   float64
#  3   HUL                  1197 non-null   float64
#  4   Maruti               1197 non-null   float64
#  5   Oil_Return           1196 non-null   float64
#  6   Indigo_Return        1134 non-null   float64
#  7   Asian_Paints_Return  1134 non-null   float64
#  8   HUL_Return           1134 non-null   float64
#  9   Maruti_Return        1134 non-null   float64
#  10  oil_lag1             1196 non-null   float64
#  11  oil_lag3             1194 non-null   float64
#  12  oil_lag7             1191 non-null   float64
# dtypes: float64(13)
# memory usage: 137.7 KB

# %%
#Summary stats
df.describe()
# Out:
#          Oil_Price       Indigo  Asian_Paints          HUL        Maruti  \
# count  1259.000000  1197.000000   1197.000000  1197.000000   1197.000000
# mean     80.883789  3220.881190   2827.872189  2357.279267  10276.523215
# std      13.070143  1445.025869    326.033913   176.100990   2747.573028
# min      58.919998  1525.322388   2109.316650  1811.667114   6187.337891
# 25%      71.839996  1926.993530   2551.917236  2239.139648   8139.094727
# 50%      79.019997  2560.972168   2882.372803  2369.480469   9927.614258
# 75%      86.269997  4466.452148   3077.279785  2464.222900  12264.357420
# max     127.980003  6155.500000   3460.254883  2939.454346  17292.000000
#
#         Oil_Return  Indigo_Return  Asian_Paints_Return   HUL_Return  \
# count  1196.000000    1134.000000          1134.000000  1134.000000
# mean      0.000703       0.001139             0.000096     0.000185
# std       0.022678       0.019594             0.013960     0.012465
# ...

# %%
#Correlation Matrix (VERY IMPORTANT)
import seaborn as sns

corr = df.corr()

sns.heatmap(corr, annot=True)
plt.title("Correlation Matrix")
plt.show()

# %%
#Distribution (RISK ANALYSIS)

df.hist(figsize=(10,8))
plt.show()

# %%
#Volatility Comparison (VERY IMPORTANT)

df.std().sort_values(ascending=False)
# Out:
# Maruti                 2747.573028
# Indigo                 1445.025869
# Asian_Paints            326.033913
# HUL                     176.100990
# Oil_Price                13.070143
# oil_lag1                 13.061013
# oil_lag3                 13.057020
# oil_lag7                 13.002692
# Oil_Return                0.022678
# Indigo_Return             0.019594
# Maruti_Return             0.014603
# Asian_Paints_Return       0.013960
# HUL_Return                0.012465
# dtype: float64

# %%
#Time Series Plot

plt.figure(figsize=(12,5))
plt.plot(df['Oil_Return'], label='Oil')
plt.plot(df['Indigo_Return'], label='Indigo')
plt.legend()
plt.title("Oil vs Airline Returns")
plt.show()
